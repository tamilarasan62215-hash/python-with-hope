# %% [markdown]
# check assign value

# %%
a=int(input("enter your value"))
if (a==10):
    print("value:",a)
    print("corret")
else:
    print("your value is wrong")
# Out:
# enter your value 10
# value: 10
# corret

# %% [markdown]
# check the password using if and else

# %%
password=input("enter your password")
if (password=="HOPE@123"):
    print("Your password is correct")
else:
    print("password wrong")
# Out:
# enter your password HOPE@123
# Your password is correct

# %% [markdown]
# catagory for people

# %%
age=int(input("Enter your age"))
if (age<=18):
    print("Children")
elif(age<=30):
    print("Adult")
elif(age<=50):
    print("Citizen")
else:
    print("senior citizen")
# Out:
# Enter your age 20
# Adult

# %% [markdown]
# Finding num positive or negative

# %%
a=int(input("enter your vallu"))
if (a>0):
    print("No is positive")
else:
    print("yes is negative")
# Out:
# enter your vallu 1
# No is positive

# %% [markdown]
# check num divisible by 5

# %%
num=int(input("enter your number"))
if(num%5==0):
    print("YES is divisible by 5")
else:
    print("NO is not divisible by 5")
# Out:
# enter your number 22
# NO is not divisible by 5
