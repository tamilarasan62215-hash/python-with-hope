# %%
stu_N=input("enter your name")
stuage=int(input("enter your age"))
print(stu_N)
if(stuage<18):
    print("childe")
elif(stuage<59):
    print("citizen") 
else:
    print('siner citizen')
# Out:
# enter your name tamil
# enter your age 88
# tamil
# siner citizen

# %%
stu_N=input("enter your name")
stu_age=int(input("enter your age"))
print(stu_N)
if(stu_age>=18):
    print("adult")
else:
    print(not adult)
# Out:
# enter your name tamil
# enter your age 22
# tamil
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       3 print(stu_N)
#       4 if(stu_age>=18):
# ----> 5     print(adult)
#       6 else:
#       7     print(not adult)
#
# NameError: name 'adult' is not defined

# %%
abc=[25,70,95,100]
for xyz in abc:
    print(xyz)
    if (xyz<35):
        print("fail conform work had need")
    elif(xyz<50):
        print("pass do well")
    elif(xyz<75):
        print("good better do well")
    elif(xyz<96):
        print("good try to achive ")
    else:
        print("exclent maintin that")
# Out:
# 25
# fail conform work had need
# 70
# good better do well
# 95
# good try to achive
# 100
# exclent maintin that

# %%
for num in range (1,10,2):
    print(num)
# Out:
# 1
# 3
# 5
# 7
# 9
