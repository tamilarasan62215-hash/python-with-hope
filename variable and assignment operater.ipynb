# %%
abc=10
cba=20
xyz=abc+cba
print(xyz)
# Out:
# 30

# %%
n1=10
n2=20
add=n1+n2
print("The additon of two number")
print("The number 1",n1)
print("The number 2",n2)
print("The answer",add)
# Out:
# The additon of two number
# The number 1 10
# The number 2 20
# The answer 30

# %%
stuname=input("enter stu name")
sturoll_no =int(input("enter roll no"))
# Out:
# enter stu name tamiol
# enter roll no 56
