# %%
print("Tamil coming to python")
# Out:
# Tamil coming to python

# %%
print (34)
# Out:
# 34

# %%
print(limat)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 print(limat)
#
# NameError: name 'limat' is not defined

# %%
Print("aws")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 Print("aws")
#
# NameError: name 'Print' is not defined

# %%
a=1
b=2
c=a+b
print(sub)
print(c)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       2 b=2
#       3 c=a+b
# ----> 4 print(sub)
#       5 print(c)
#
# NameError: name 'sub' is not defined
