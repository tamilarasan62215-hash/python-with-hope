# %%
print("HOPE AI")
# Out:
# HOPE AI

# %%
instu=input("Enter your institue name")
print("institue name =",instu)
# Out:
# Enter your institue name HOPE AI
# institue name = HOPE AI

# %%
name=input("enter your name")
age=int(input("entr your age"))
school=input("enter your school name")
drgree=input("enter your drgree")
print("NAME = ",name)
print("AGE = ",age)
print("SCHOOL = ",school)
print("DRGREE = ",drgree)
# Out:
# enter your name Tamil
# entr your age 25
# enter your school name Don Bosco
# enter your drgree MSC(CS)
# NAME =  Tamil
# AGE =  25
# SCHOOL =  Don Bosco
# DRGREE =  MSC(CS)

# %%
CALCULATER FOR ADD,SUB,MUL,DIV,FLOOR DIV,MODULO,POWER

# %%
def calculater ():
    if(CALC=="add"):
        print("add = ",num1+num2)
    elif(CALC=="sub"):
        print("sub = ",num1-num2)
    elif(CALC=="mul"):
        print("mul = ",num1*num2)
    elif(CALC=="div"):
        print("div = ",num1/num2)
    elif(CALC=="flo div"):
        print("flo div = ",num1//num2)
    elif(CALC=="model"):
        print("model = ",num1%num2)
    elif(CALC=="power"):
        print("power = ",num1**num2)
    else:
        print("THIS VERSION  addition, subtraction, multiplication, division, floor-division, model, and power ONLY ")

# %%
num1=int(input("enter valu 1 ="))
num2=int(input("enter valu 2 ="))
CALC=input("add/sub/mul/div/flo div/model/power")
add=calculater()
# Out:
# enter valu 1 = 43
# enter valu 2 = 34
# add/sub/mul/div/flo div/model/power add
# add =  77

# %%
num1=int(input("enter valu 1 ="))
num2=int(input("enter valu 2 ="))
CALC=input("add/sub/mul/div/flo div/model/power")
sub=calculater()
# Out:
# enter valu 1 = 43
# enter valu 2 = 34
# add/sub/mul/div/flo div/model/power sub
# sub =  9

# %%
num1=int(input("enter valu 1 ="))
num2=int(input("enter valu 2 ="))
CALC=input("add/sub/mul/div/flo div/model/power")
mult=calculater()
# Out:
# enter valu 1 = 63
# enter valu 2 = 97
# add/sub/mul/div/flo div/model/power mul
# mul =  6111

# %%
num1=int(input("enter valu 1 ="))
num2=int(input("enter valu 2 ="))
CALC=input("add/sub/mul/div/flo div/model/power")
division=calculater()
# Out:
# enter valu 1 = 76
# enter valu 2 = 31
# add/sub/mul/div/flo div/model/power div
# div =  2.4516129032258065

# %%
num1=int(input("enter valu 1 ="))
num2=int(input("enter valu 2 ="))
CALC=input("add/sub/mul/div/flo div/model/power")
floor_div=calculater()
# Out:
# enter valu 1 = 76
# enter valu 2 = 31
# add/sub/mul/div/flo div/model/power flo div
# flo div =  2

# %%
num1=int(input("enter valu 1 ="))
num2=int(input("enter valu 2 ="))
CALC=input("add/sub/mul/div/flo div/model/power")
module=calculater()
# Out:
# enter valu 1 = 76
# enter valu 2 = 31
# add/sub/mul/div/flo div/model/power model
# model =  14

# %%
num1=int(input("enter valu 1 ="))
num2=int(input("enter valu 2 ="))
CALC=input("add/sub/mul/div/flo div/model/power")
power=calculater()
# Out:
# enter valu 1 = 4
# enter valu 2 = 4
# add/sub/mul/div/flo div/model/power power
# power =  256
